# %% [markdown]
# *David Sneider Ovalle Pineda /*
# *Algoritmos /*
# *Laboratorio* *8*

# %%
import pydot
import matplotlib.pyplot as plt
import math  as m
import itertools
import networkx as nx
from collections import defaultdict 
from IPython.display import Image, display

# %% [markdown]
# **1)**

# %%
options = {
    "node_color": "white",
    "edgecolors": "black"}
def flip(lis, pos): 
  if pos == 1:
    return lis
  elif pos == len(lis):
    l = lis[::-1]
    return l
  else:
    l1 = lis[0:pos]
    l1 = l1[::-1]
    l2 = lis[pos:]
    return l1 + l2
def GraficaRedPancakes(n): 
  num_permuta = m.factorial(n)
  permutacion = list(range(1,n+1))
  permutaciones = list(itertools.permutations(permutacion))
  G=nx.Graph()
  for i in range(0,num_permuta):
    G.add_node(lstr(permutaciones[i]),color="red")
  for i in range(0, num_permuta):
    for j in range(2, n+1):
      flipped = flip(permutaciones[i], j)
      for k in range(0, num_permuta):
        if flipped == permutaciones[k]:
          edge =  (lstr(permutaciones[i]), lstr(permutaciones[k]))
          G.add_edge(*edge,color="black")
          break
  nx.draw(G, with_labels = True,**options)
  plt.show()

# %%
print("Red Pancake para n = 2")
GraficaRedPancakes(2)
print("Red Pancake para n = 3")
GraficaRedPancakes(3)
print("Red Pancake para n = 4")
GraficaRedPancakes(4)
print("Red Pancake para n = 5")
GraficaRedPancakes(5)
print("Red Pancake para n = 6")
GraficaRedPancakes(6)
# Out:
# Red Pancake para n = 2
# Red Pancake para n = 3
# Red Pancake para n = 4
# Red Pancake para n = 5
# Red Pancake para n = 6

# %%
def lstr(p):
        return ''.join([str(elem)  for elem in p])

# %%
def goodLevel(s,L):  
        if s == sorted(s):
         return True
        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="digraph")
         
        queue = [] 
  
        queue.append([s,0]) 
        visited[lstr(s)] = True
  
        while queue: 
  
            e = queue.pop(0)
            s = e[0]
            l = e[1] 
            graph[lstr(s)]=[]

            flag = False
            for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]
                if(d == sorted(d)):
                     flag = True
            if flag:
              node = pydot.Node(lstr(s),style="filled", fillcolor="yellow")
            else: 
              node = pydot.Node(lstr(s))

            G.add_node(node)
            
            if(s != sorted(s)) and (l < L):
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]  
                if (d != s) and not(lstr(d) in visited.keys()):
                 
                  if(d != sorted(d)):
                     node = pydot.Node(lstr(d))
                  else:
                    node = pydot.Node(lstr(d),style="filled", fillcolor="green") 
                    return True
                  G.add_node(node)
                  edge = pydot.Edge(lstr(s),lstr(d))
                  G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append([d,l+1]) 
                  visited[lstr(d)] = True 
              
        return False
def Numberlittle(n):
  if n == 1:
    return 0
  max = 1
  num_permuta = m.factorial(n)
  permutacion = list(range(1,n+1))
  permutaciones = list(itertools.permutations(permutacion))
  for i in range(0,num_permuta):
    for j in range(max, 2*n):
      perm = list(permutaciones[i])
      if goodLevel(perm, j):
        max = j
        break
  return max

# %%
print("Pancake Number for n = ", 3)
print(Numberlittle(3))
print("Pancake Number for n = ", 4)
print(Numberlittle(4))
print("Pancake Number for n = ", 5)
print(Numberlittle(5))
print("Pancake Number for n = ", 6)
print(Numberlittle(6))
# Out:
# Pancake Number for n =  3
# 3
# Pancake Number for n =  4
# 4
# Pancake Number for n =  5
# 5
# Pancake Number for n =  6
# 7

# %%
def goodLevels(s,L):  
        if s == sorted(s):
         return True
        graph = defaultdict()
        visited = defaultdict()
        queue = [] 
        queue.append([s,0]) 
        visited[lstr(s)] = True
  
        while queue: 
            e = queue.pop(0)
            s = e[0]
            l = e[1] 
            graph[lstr(s)]=[]
            if(s != sorted(s)) and (l < L):
              for i in range(len(s)-1):
                d = s[i+1::-1] + s[i+2:]  
                if (d != s) and not(lstr(d) in visited.keys()):
                  if(d == sorted(d)):
                    return True
                  graph[lstr(s)].append(lstr(d))
                  queue.append([d,l+1]) 
                  visited[lstr(d)] = True 
        return False
def simplifiedPancake(n):
  if n == 1:
    return 0
  max = 1
  num_permuta = m.factorial(n)
  permutacion = list(range(1,n+1))
  permutaciones = list(itertools.permutations(permutacion))
  for i in range(0,num_permuta):
    for j in range(max, 2*n):
      perm = list(permutaciones[i])
      if goodLevels(perm, j):
        max = j
        break
  return max

# %%
n = 1
while n <= 25:
  print("The pancake number of", n, " is ",simplifiedPancake(n))
  n = n+1
# Out:
# The pancake number of 1  is  0
# The pancake number of 2  is  1
# The pancake number of 3  is  3
# The pancake number of 4  is  4
# The pancake number of 5  is  5
# The pancake number of 6  is  7
# The pancake number of 7  is  8
# The pancake number of 8  is  9

# %% [markdown]
# ##Biggest p_n calculated was for n = 8, which gave the result p_8 = 9

# %%
def twoHandFlip(lis, pos1, pos2): 
  l1= []
  l2 = []
  l3 = []
  if pos1 == pos2:
    return lis
  if pos1 > 1:
    l1 = lis[0:pos1-1]
  if pos2 < len(lis):
    l3 = lis[pos2:]
  l2 = lis[pos1-1:pos2]
  l2 = l2[::-1]
  return l1 + l2 + l3

# %%
p = [5,2,3,4,1]
for i in range(1, len(p)):
  for j in range(i+1, len(p)+1):
    print(twoHandFlip(p,i,j))
# Out:
# [2, 5, 3, 4, 1]
# [3, 2, 5, 4, 1]
# [4, 3, 2, 5, 1]
# [1, 4, 3, 2, 5]
# [5, 3, 2, 4, 1]
# [5, 4, 3, 2, 1]
# [5, 1, 4, 3, 2]
# [5, 2, 4, 3, 1]
# [5, 2, 1, 4, 3]
# [5, 2, 3, 1, 4]

# %%
def lstr(p):
  return ''.join([str(elem)  for elem in p])
def ModifiedBFSPreSols(s): 

        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="digraph")
        
        queue = [] 
  
        queue.append(s) 
        visited[lstr(s)] = True
  
        while queue: 
  
            s = queue.pop(0) 
            graph[lstr(s)]=[]

            flag = False
            for i in range(1, len(p)):
                for j in range(i+1, len(p)+1):
                 d = twoHandFlip(s, i, j)
                 if(d == sorted(d)):
                  flag = True
            if flag:
              node = pydot.Node(lstr(s),style="filled", fillcolor="yellow")
            else: 
              node = pydot.Node(lstr(s))

            G.add_node(node)
            
            if(s != sorted(s)):
              for i in range(1, len(p)):
                for j in range(i+1, len(p)+1):
                 d = twoHandFlip(s, i, j)
                 if (d != s) and not(lstr(d) in visited.keys()):
                 
                  if(d != sorted(d)):
                     node = pydot.Node(lstr(d))
                  else:
                    node = pydot.Node(lstr(d),style="filled", fillcolor="green") # first sorted green
                  
                  G.add_node(node)
                  edge = pydot.Edge(lstr(s),lstr(d))
                  G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append(d) 
                  visited[lstr(d)] = True 
              
        im = Image(G.create_png())
        display(im)

# %%
print("Dos espatulas")
p = [1,3,2]
ModifiedBFSPreSols(p)
p = [4,3,1,2]
ModifiedBFSPreSols(p)
# Out:
# Dos espatulas

# %%
def lstr(p):
        return ''.join([str(elem)  for elem in p])
def ModifiedBFSPreSolsLevel(s,L):  
        graph = defaultdict()
        visited = defaultdict()
        G = pydot.Dot(graph_type="digraph")
        
        queue = [] 
  
        queue.append([s,0]) 
        visited[lstr(s)] = True
  
        while queue: 
            e = queue.pop(0)
            s = e[0]
            l = e[1] 
            graph[lstr(s)]=[]

            flag = False
            for i in range(1, len(p)):
              for j in range(i+1, len(p)+1):
                  d = twoHandFlip(s, i, j)
                  if(d == sorted(d)):
                     flag = True
            if flag:
              node = pydot.Node(lstr(s),style="filled", fillcolor="yellow")
            else: 
              node = pydot.Node(lstr(s))
            G.add_node(node)   
            if(s != sorted(s)) and (l < L):
              for i in range(1, len(p)):
                for j in range(i+1, len(p)+1):
                 d = twoHandFlip(s, i, j)
                 if (d != s) and not(lstr(d) in visited.keys()):
                 
                  if(d != sorted(d)):
                     node = pydot.Node(lstr(d))
                  else:
                    node = pydot.Node(lstr(d),style="filled", fillcolor="green") 
                  G.add_node(node)
                  edge = pydot.Edge(lstr(s),lstr(d))
                  G.add_edge(edge)
                  graph[lstr(s)].append(lstr(d))
                  queue.append([d,l+1]) 
                  visited[lstr(d)] = True 
              
        im = Image(G.create_png())
        display(im)

# %%
print("Pancake tree of one level using two Spatulas")
print("Arbol del Pancake de un nivel usando dos espatulas")
p = [4,3,2,1,5]
ModifiedBFSPreSolsLevel(p,1)
# Out:
# Pancake tree of one level using two Spatulas
# Arbol del Pancake de un nivel usando dos espatulas

# %%
print("Arbol del Pancake de dos niveles usando dos espatulas")
p = [4,3,2,1,5]
ModifiedBFSPreSolsLevel(p,2)
# Out:
# Arbol del Pancake de dos niveles usando dos espatulas
